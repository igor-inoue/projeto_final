# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

df = pd.read_csv('dados.dat',delimiter="\t",header=None, names=[r"$t_{med}$"])
df.index = df.index + 1

sns.set_theme()

df[r"$N^2\ln N^2$"] = df.index ** 2 + np.log(df.index ** 2)

#x = np.linspace(0.8, 15, 100)
#plt.plot(x, x**2 * np.log(x**2))

#sns.relplot(data=df)

#sns.lmplot(data=df)

#df.plot()
df
# Out:
#       $t_{med}$  $N^2\ln N^2$
# 1      0.000000      1.000000
# 2      0.690000      5.386294
# 3      2.045000     11.197225
# 4      6.379412     18.772589
# 5     21.513462     28.218876
# 6     48.947296     39.583519
# 7     89.905998     52.891820
# 8    171.847687     68.158883
# 9    351.234161     85.394449
# 10   513.713867    104.605170
# 11   854.776611    125.795791
# 12  1114.953491    148.969813
