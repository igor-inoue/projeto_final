# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

x = np.linspace(1, 12, 100)
plt.plot(x, x**2 * np.log(x**2) )

ax = plt.gca()

df = pd.read_csv('dados.dat',delimiter="\t")
df.index = df.index + 1

sns.relplot(data=df)

df.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 11
#       7 plt.plot(x, x**2 * np.log(x**2) )
#       9 ax = plt.gca()
# ---> 11 sns.relplot(data=df)
#      13 df = pd.read_csv('dados.dat',delimiter="\t")
#      14 df.index = df.index + 1
#
# NameError: name 'df' is not defined
